# %% [markdown]
# # Nome: Cauã Campos de Souza e Silva
# ## Matricula: 651

# %% [markdown]
# ---

# %% [markdown]
# ### Material de Apoio:
# * [Estatística Computacional em Python - Apostila](https://des.ufla.br/~danielff/meusarquivospdf/ECPython.pdf)
#
#
# * [Python para análise de dados - Medidas de tendência central](https://youtu.be/rgkGYJAAI4E?si=KUDBsm9IPFch3Gmz)

# %% [markdown]
# ---

# %% [markdown]
# ## Atividade 1 – Análise do Tempo de Permanência nos Espaços Técnicos do Hacktown

# %% [markdown]
# Durante o Hacktown, evento que mistura inovação, tecnologia e criatividade em Santa Rita do Sapucaí, foi realizada uma pesquisa entre os visitantes que passaram pelos espaços técnicos da feira (como painéis de tecnologia, oficinas de IA, estandes de protótipos, etc.).
#
# A equipe do evento mediu o tempo médio de permanência (em minutos) dos participantes em 20 estandes diferentes. Esses dados serão utilizados para repensar o design de rotas e experiências nas próximas edições.
#
# Você recebeu os dados do tempo de permanência dos visitantes (em minutos) em diferentes locais:
#
# | Local de Permanência                        | Tempo de Permanência |
# |--------------------------------------------|----------------------|
# | Teatro Inatel                              | 53                   |
# | Braseiro Restaurante                       | 32                   |
# | ETE - Sala 82                              | 42                   |
# | Real Palace                                | 36                   |
# | Be Bold                                    | 35                   |
# | Inatel - Sala de Física                    | 15                   |
# | ETE - Auditório Sinhá Moreira              | 52                   |
# | Inatel - CDGHub                            | 24                   |
# | Casa Dinamarca                             | 37                   |
# | ETE - Sala 64                              | 43                   |
# | Associação José do Patrocínio              | 17                   |
# | Inatel - Auditório Aureliano Chaves        | 56                   |
# | Escola Sânico Teles - Ginásio              | 34                   |
# | Inatel - Laboratório de Ideação            | 25                   |
# | Inatel - Sala 03                           | 37                   |
# | Bar e Restaurante do Dimas                 | 31                   |
# | Loja Maçônica                              | 18                   |
# | Boteco do Tio João                         | 33                   |
# | Inatel - Sala 25                           | 39                   |
# | ETE - Sala 82                              | 40                   |

# %%
# Plotar gráficos
import seaborn as sns
import matplotlib.pyplot as plt

# Analise de dados
import numpy as np
import pandas as pd

# %%
# Dicionário de dados
tabela = {
    "Local de Permanência": [
        "Teatro Inatel", "Braseiro Restaurante", "ETE - Sala 82", "Real Palace",
        "Be Bold", "Inatel - Sala de Física", "ETE - Auditório Sinhá Moreira",
        "Inatel - CDGHub", "Casa Dinamarca", "ETE - Sala 64",
        "Associação José do Patrocínio", "Inatel - Auditório Aureliano Chaves",
        "Escola Sânico Teles - Ginásio", "Inatel - Laboratório de Ideação",
        "Inatel - Sala 03", "Bar e Restaurante do Dimas", "Loja Maçônica",
        "Boteco do Tio João", "Inatel - Sala 25", "ETE - Sala 82"
    ],
    "Tempo de Permanência": [
        53, 32, 42, 36, 35, 15, 52, 24, 37, 43,
        17, 56, 34, 25, 37, 31, 18, 33, 39, 40
    ]
}

dados = pd.DataFrame(tabela)
display(dados)
# Out:
#                    Local de Permanência  Tempo de Permanência
# 0                         Teatro Inatel                    53
# 1                  Braseiro Restaurante                    32
# 2                         ETE - Sala 82                    42
# 3                           Real Palace                    36
# 4                               Be Bold                    35
# 5               Inatel - Sala de Física                    15
# 6         ETE - Auditório Sinhá Moreira                    52
# 7                       Inatel - CDGHub                    24
# 8                        Casa Dinamarca                    37
# 9                         ETE - Sala 64                    43
# 10        Associação José do Patrocínio                    17
# 11  Inatel - Auditório Aureliano Chaves                    56
# 12        Escola Sânico Teles - Ginásio                    34
# 13      Inatel - Laboratório de Ideação                    25
# 14                     Inatel - Sala 03                    37
# 15           Bar e Restaurante do Dimas                    31
# 16                        Loja Maçônica                    18
# 17                   Boteco do Tio João                    33
# 18                     Inatel - Sala 25                    39
# 19                        ETE - Sala 82                    40

# %% [markdown]
# ---
# ### Parte 1 - Tendência Central e Interpretação
#
# Obs: Se necessário for, reordene os dados em ordem crescente ou decrescente (rol).

# %%
# Ordenar o DataFrame pelo tempo de permanência (crescente)
df_ordenado = dados.sort_values(by='Tempo de Permanência', ascending=True).reset_index(drop=True)

# Média do tempo de permanência
media = dados['Tempo de Permanência'].mean()

# Mediana do tempo de permanência
mediana = dados['Tempo de Permanência'].median()

# Moda do tempo de permanência
moda = dados['Tempo de Permanência'].mode()   # retorna uma Series (pode haver mais de uma moda)

# %% [markdown]
# 1. Calcule a média, a mediana e a moda dos tempos de permanência.
#
# <img src="data:image/png;base64,..."/>
# <img src="data:image/png;base64,..."/>

# %%
print(f"Média: {media}")
print(f"Mediana: {mediana}")
print(f"Moda: {', '.join(map(str, moda))}")
# Out:
# Média: 34.95
# Mediana: 35.5
# Moda: 37

# %% [markdown]
# 2. Esses valores são próximos? Em sua opinião, qual dessas medidas representa melhor o comportamento do público no Hacktown? Justifique.

# %% [markdown]
# *Resposta*: Sim, os valores são bem próximos. Acredito que a mediana represente melhor, pois divide os dados ao meio e não é influenciada por valores extremos, deixando a informação mais fiel.

# %% [markdown]
# 3. Identifique os locais com tempos de permanência muito acima ou abaixo da média. O que isso pode indicar sobre esses espaços?

# %%
# calcula o desvio padrão do tempo de permanência
desvio = dados['Tempo de Permanência'].std()

# seleciona apenas os locais com tempo MUITO acima da média
muito_acima = dados.loc[
    dados['Tempo de Permanência'] > media + desvio,
    'Local de Permanência'
]

# seleciona apenas os locais com tempo MUITO abaixo da média
muito_abaixo = dados.loc[
    dados['Tempo de Permanência'] < media - desvio,
    'Local de Permanência'
]

print(f"Desvio padrão: {desvio:.2f}\n")

# index=false pra n mostrar o indice
print("Locais MUITO acima da média:")
print(muito_acima.to_string(index=False))

print("\nLocais MUITO abaixo da média:")
print(muito_abaixo.to_string(index=False))
# Out:
# Desvio padrão: 11.43
#
# Locais MUITO acima da média:
#                       Teatro Inatel
#       ETE - Auditório Sinhá Moreira
# Inatel - Auditório Aureliano Chaves
#
# Locais MUITO abaixo da média:
#       Inatel - Sala de Física
# Associação José do Patrocínio
#                 Loja Maçônica

# %% [markdown]
# Resposta:
#
# Locais acima da média geralmente possuem atividade mais longas e maior engajamento, como palestras/apresentações.
#
# ================================
#
# Locais abaixo da média geralmente sugerem circulação rápida ou uso momentâneo dos espaços, tendo menos retenção do público.

# %% [markdown]
# ---
# ### Parte 2 – Separatrizes (Quartis)

# %%
# Função para calcular os quartis
quartis = dados['Tempo de Permanência'].quantile([0.25, 0.5, 0.75])

# %% [markdown]
# 4. Calcule os quartis Q1, Q2 (mediana) e Q3.
# <br><img src="data:image/png;base64,..." alt="Descrição da imagem" width="300"/>

# %%
# resultados
print("Q1:", quartis.loc[0.25])
print("Q2 (mediana):", quartis.loc[0.5])
print("Q3:", quartis.loc[0.75])
# Out:
# Q1: 29.5
# Q2 (mediana): 35.5
# Q3: 40.5

# %% [markdown]
# 5. Quais espaços estão abaixo de Q1? O que pode estar acontecendo nesses lugares?

# %% [markdown]
# Resposta:
#
# - Inatel - Sala de Física
# - Associação José do Patrocínio
# - Inatel - CDGHub
# - Inatel - Laboratório de Ideação
# - Loja Maçônica
#
# São os que o tempo de permanência é menor que o observado para 25% dos locais analisados. Esses lugares não tem retenção público e tendem a permanecer por pouco tempo.

# %% [markdown]
# 6. Quais locais estão acima de Q3? Isso pode indicar algo positivo ou negativo para a organização?

# %% [markdown]
# Resposta:
#
# - Teatro Inatel
# - ETE – Auditório Sinhá Moreira
# - Inatel – Auditório Aureliano Chaves
# - ETE – Sala 64
# - ETE – Sala 82
#
# Esses locais possuem mais engajamento do público, atividades mais relevantes ou programações mais longas, típicas de auditórios e salas de palestras.

# %% [markdown]
# ---
# ### Parte 3 – Dispersão

# %%
# Função para calcular a amplitude
amplitude = dados['Tempo de Permanência'].max() - dados['Tempo de Permanência'].min()

# Função para calcular a variância amostral
def variancia(dados):
    media = sum(dados) / len(dados)
    return sum((x - media) ** 2 for x in dados) / (len(dados) - 1)

# Função para calcular o desvio padrão amostral
def desvio_padrao(dados):
    return variancia(dados) ** 0.5

# %% [markdown]
# 7. Calcule:

# %% [markdown]
# - Amplitude:
# <br><img src="data:image/png;base64,..." alt="Descrição da imagem" width="500"/>

# %%
print("Amplitude:", amplitude)
# Out:
# Amplitude: 41

# %% [markdown]
# - Variância (amostral):
# <br><img src="data:image/png;base64,..." alt="Descrição da imagem" width="300"/>

# %%
# Cálculo da variância amostral
var_amostral = variancia(dados['Tempo de Permanência'])

print("Variância (amostral):", round(var_amostral, 2))
# Out:
# Variância (amostral): 130.58

# %% [markdown]
# - Desvio Padrão (amostral):
# <br><img src="data:image/png;base64,..." alt="Descrição da imagem" width="300"/>

# %%
# Cálculo do desvio padrão amostral
dp_amostral = desvio_padrao(dados['Tempo de Permanência'])

print("Desvio Padrão (amostral):", round(dp_amostral, 2))
# Out:
# Desvio Padrão (amostral): 11.43

# %% [markdown]
# 8. Os tempos de permanência variam muito entre os locais? Como essa dispersão influencia as decisões de alocação de palestras, dinâmicas ou recursos?

# %% [markdown]
# Resposta: Sim, os tempos de permanência variam consideravelmente entre os locais. A amplitude elevada (41 minutos) e o desvio padrão amostral (~11,36 minutos) indicam uma dispersão significativa, ou seja, alguns espaços concentram o público por muito mais tempo do que outros.

# %% [markdown]
# ---
# ### Parte 4 – Visualização de Dados

# %%
# Função para Histograma
def plot_histograma(dados, coluna, bins=10):
    """
    Plota um histograma para a coluna numérica especificada.
    :param dados: DataFrame
    :param coluna: Nome da coluna numérica
    :param bins: Número de intervalos do histograma
    """
    plt.figure(figsize=(8,5))
    plt.hist(dados[coluna], bins=bins, color='skyblue', edgecolor='black')
    plt.title(f"Histograma - {coluna}")
    plt.xlabel(coluna)
    plt.ylabel("Frequência")
    plt.axvline(dados[coluna].mean(), color='red', linestyle='--', label=f'Média: {dados[coluna].mean():.2f}')
    plt.legend()
    plt.show()

# Função para Boxplot
def plot_boxplot(dados, coluna):
    """
    Plota um boxplot para a coluna numérica especificada.
    :param dados: DataFrame
    :param coluna: Nome da coluna numérica
    """
    plt.figure(figsize=(8,3))
    sns.boxplot(x=dados[coluna], color='lightgreen')
    plt.title(f"Boxplot - {coluna}")
    plt.xlabel(coluna)
    plt.show()

# %% [markdown]
# 9. Crie um histograma para visualizar a distribuição dos tempos.

# %%
plot_histograma(dados, 'Tempo de Permanência', bins=10)

# %% [markdown]
# 10. Crie um boxplot, indicando os quartis, a mediana e possíveis outliers.

# %%
plot_boxplot(dados, 'Tempo de Permanência')

# %% [markdown]
# 11. Com base no boxplot, quais locais podem ser considerados outliers? Eles precisam de atenção especial?

# %% [markdown]
# Resposta: Os outliers são os locais com tempos muito baixos (cerca de 15–18 minutos) e muito altos (acima de 50 minutos).
#
# Os tempos muito baixos podem indicar espaços de passagem ou pouco atrativos, enquanto os tempos muito altos podem indicar alto engajamento — ou possíveis problemas como lotação excessiva.
# Eles merecem atenção, pois mostram comportamentos fora do padrão que ajudam a melhorar a organização do evento.
