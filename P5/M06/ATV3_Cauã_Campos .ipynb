# %% [markdown]
# ## Nome: Cauã Campos de Souza e Silva
# ## Matrícula: 651

# %% [markdown]
# ---

# %% [markdown]
# # PARTE PRÁTICA

# %% [markdown]
# ## Atividade 3 – Análise de Erros em Medições Experimentais
#
# Questão 1.
#
# Um professor de Engenharia Química, realizou um experimento com seus alunos
# à respeito do calor específico da água. O experimento consiste em aquecer uma
# massa de água com um calorímetro e com isso medir a variação da temperatura, assim podendo calcular os
# novos valores do calor específico. Porém, os resultados obtidos foram diferentes do
# valor exato do calor específico da água. Devido à isso o professor
# passou esses dados em uma tabela para você fazer um estudo sobre erros e métodos numéricos.
#
# Importante citar que o valor do calor específico da água é de aproximadamente 4,186 kJ/(kg·K)
#
#
# Os resultados dos alunos estão na tabela abaixo:
#
# | Alunos               | Valor Medido (KJ) |
# |-----------------------------------|---------------------|
# | Soned             | 4.19           |
# | Karina        | 4.18               |
# | Renzo               |     4.179           |
# | Renan      | 4.188               |
# | Aquino            | 4.202             |
# | Evandro       | 4.188             |
#
#
# Seu objetivo é analisar esses dados e calcular diferentes métricas de erro,
# utilizando Python e bibliotecas como **pandas**, **numpy** e **matplotlib**.
#
# ---

# %%
from IPython.display import display, Markdown
# Importando bibliotecas

#Analise de dados
import pandas as pd
import numpy as np

#Plotar gráficos
import matplotlib.pyplot as plt

# %%
#Tabela de dados
tabela = {
    "Alunos": [
        "Soned", "Karina", "Renzo",
        "Renan", "Aquino",
        "Evandro"
    ],
    "Valor Medido (K*J)": [4.19, 4.18, 4.179, 4.188, 4.202, 4.188]
}

dados = pd.DataFrame(tabela)
display(dados)

# %% [markdown]
# ### Parte 1 - Erro Absoluto, Erro Relativo e Erro Percentual

# %%
# Ordenando igual a atividade passada
df_ordenado = dados.sort_values(by='Valor Medido (K*J)', ascending=True).reset_index(drop=True)

# Valor teórico
valor_teorico = 4.186

# %% [markdown]
# Calcule o Erro Absoluto, o Erro Relativo e o Erro Percentual dos valores medidos.

# %%
# Erro Absoluto
df_ordenado["Erro Absoluto"] = np.abs(
    valor_teorico - df_ordenado["Valor Medido (K*J)"]
)

# Erro Relativo (Ea / |Vm|)
df_ordenado["Erro Relativo"] = (
    df_ordenado["Erro Absoluto"] / np.abs(df_ordenado["Valor Medido (K*J)"])
)

# Erro Percentual
df_ordenado["Erro Percentual (%)"] = (
    df_ordenado["Erro Relativo"] * 100
)

display(df_ordenado)

# %% [markdown]
# **Formulário para cálculo de erros do calor específico**
#
# - Erro Absoluto:
# $$E_a = |V_t - V_m|$$
#
# - Erro Relativo:
# $$E_r = \frac{E_a}{|V_m|}$$
#
# - Erro Percentual:
# $$E_p = E_r \times 100\%$$
#
# Onde:
# - $V_t$ = valor teórico do calor específico (4,186 kJ/(kg·K))
# - $V_m$ = valor medido pelo aluno

# %% [markdown]
# ### Parte 2 - Arredondamento e Truncamento

# %% [markdown]
# Um engenheiro de produção está desenvolvendo um sistema para controle de corte de peças metálicas.
# O equipamento mede o comprimento das peças, mas as medições apresentam várias casas decimais,
# sendo necessário arredondar os valores para atender às especificações técnicas da indústria.
# Esse engenheiro, a fim de deixar mais didático as suas medições, decidiu propor para você uma série de tarefas,
# e você deverá auxiliá-lo nessa importante atividade.
#
# As medidas coletadas pelo engenheiro estão anotadas na tabela:

# %% [markdown]
# | Peça              | Comprimento medido (cm) |
# |-----------------------------------|---------------------|
# | P1             | 12.3456           |
# | P2        |           9.8765     |
# | P3               |     15.5555          |
# | P4      | 7.4999            |
# | P5            | 10.0501            |
#
# As terefas pedidas por eles são:

# %% [markdown]
# ### 1 - Faça um DataFrame para organização visual dos dados

# %%
# DataFrame das medições
df_pecas = pd.DataFrame({
    "Peça": ["P1", "P2", "P3", "P4", "P5"],
    "Comprimento medido (cm)": [12.3456, 9.8765, 15.5555, 7.4999, 10.0501]
})

df_pecas

# %% [markdown]
# ### 2 - Arredonde todos os valores para 2 casas decimais, para me ajudar nos cálculos

# %%
# DataFrame das medições (com 2 casas decimais)
df_pecas = pd.DataFrame({
    "Peça": ["P1", "P2", "P3", "P4", "P5"],
    "Comprimento medido (cm)": [12.35, 9.88, 15.56, 7.50, 10.05]
})

df_pecas

# %% [markdown]
# ### 3 - Após isso, trunque os valores para 1 casa decimal

# %%
# Truncando os valores para 1 casa decimal
# Isso se faz usando o np.trunc() para cortar as casas excedentes (n arredonda)

df_pecas["Comprimento medido (cm)"] = np.trunc(
    df_pecas["Comprimento medido (cm)"] * 10
) / 10

df_pecas

# %% [markdown]
# ### 4 - Mostre para mim depois, o valor inteiro mais próximo

# %%
# round(0) é para arredondar para 0 casas decimais (deixar o num. inteiro), o astype ele tira a casa decimal

inteiro_proximo = df_pecas["Comprimento medido (cm)"].round(0).astype(int)

# %% [markdown]
# ### 5 - E me mostrar os resultados dentro de uma tabela

# %%
# A tabela mostra a peça e o inteiro mais próximo calculado anteriormente

tabela_resultados = pd.DataFrame({
    "Peça": df_pecas["Peça"],
    "Inteiro mais próximo": inteiro_proximo
})

tabela_resultados

# %% [markdown]
# <span style="font-size:90%">
#
# **Guia Rápido: Arredondamento e Truncamento**
#
# - Arredondar para n casas decimais: `dados["Comprimento Medido (cm)"].round(0)`
# - Truncar para n casas decimais: `np.trunc(dados["Comprimento Medido (cm)"] * 10) / 10`
# - Arredondar para inteiro mais próximo: `dados["Comprimento Medido (cm)"].round(0).astype(int)`
#
# </span>

# %% [markdown]
# # Parte Teórica

# %% [markdown]
# ## **Questão 1.**
#
# Julgue as afirmativas abaixo como V (Verdadeiro) ou F (Falso) e justifique as que forem Falsas.

# %% [markdown]
# 1. É possível representar qualquer grandeza física em termos das unidades básicas da Física. ()
#
# 2. O instrumento de medida escolhido para medir uma grandeza deve ser coerente com aquilo que se deseja medir. ()
#
# 3. A incerteza não precisa ser levada em consideração e não é necessária para compararmos os dados. ()
#
# 4. O erro relativo é calculado dividindo o erro absoluto pelo valor teórico. ()
#
# 5. O número de algoritmos significativos de uma grandeza é determinado pela sua incerteza. ()

# %% [markdown]
# ### **Resposta:**
#
# 1.   V
# 2.   V
# 3.   F - Justificativa: A incerteza é importante porque mostra o quanto a medição pode variar. Sem considerar a incerteza, não é possível saber se dois resultados realmente são diferentes ou se a diferença ocorreu apenas por erro de medição.
#
# 4.   F - Justificativa: O erro relativo não é calculado usando o valor teórico no denominador. De acordo com a fórmula, ele é calculado dividindo o erro absoluto pelo valor medido.
#
# 5.   V

# %% [markdown]
# ## **Questão 2.**
#
# Quando você faz a medição de alguma grandeza, com um instrumento de medição qualquer, em qual conjunto cai a medida que você
# obteve?
#
# Conjunto dos números Naturais, Inteiros, Racionais, Irracionais, Reais ou Complexos? Justifique sua resposta

# %% [markdown]
# ### **Resposta:**
# A medida que a gente obtém usando um instrumento de medição faz parte do conjunto dos números reais. Isso acontece porque o resultado da medição quase sempre tem casas decimais, tipo 12,35 cm ou 4,18 kJ. Então não fica só em números inteiros. Como os números reais incluem tanto inteiros quanto decimais, é nesse conjunto que as medições se encaixam.

# %% [markdown]
# ## **Questão 3.**
#
# Suponhamos que deseje medir o tamanho de um besouro.
# Foi decidido também, o que caracteriza o tamanho do besouro, qual das alternativas abaixo melhor caracteriza a medida
# do tamanho do besouro?

# %% [markdown]
# ![image.png](
# data:image/jpeg;base64,...)

# %% [markdown]
# a) Entre 0 e 1 cm
#
# b) Entre 1 e 2 cm
#
# c) Entre 1,5 e 1,6
#
# d) Entre 1,54 e 1,56
#
# e) Entre 1,546 e 1,547

# %% [markdown]
# ### **Resposta:**
#
# Letra C.
#
# Com esse tipo de régua, não se pode afirmar algum valor mais preciso que esse.

# %% [markdown]
# ## **Questão 4.**
#
#
# Seja o número a = 4876 representado por a
# ′ = 4875,8 e seja o número 𝑦 = 12,7 representado por
# 𝑦
# ′ = 12,6.
#
# Pode-se dizer que ambos os números estão representados com a mesma precisão?

# %% [markdown]
# ### **Resposta:**
# Não. Mesmo que os dois tenham sido aproximados, eles não têm a mesma precisão.
